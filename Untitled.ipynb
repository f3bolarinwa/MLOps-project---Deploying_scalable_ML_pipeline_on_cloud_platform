# %%
import pandas as pd
import joblib
import yaml
from sklearn.model_selection import train_test_split
from ML.data import process_data
from ML.model import train_model, compute_model_metrics, inference, slice_data #, process_data

# %%
model = joblib.load("model/classifier_model.joblib")

# %%
#model = joblib.load('./model/classifier_model.joblib')

# %%
# Reading configuration file
with open('config.yaml') as f:
    config = yaml.load(f, Loader=yaml.FullLoader)

# %%
# loading in the data.
df = pd.read_csv('./data/census_clean.csv')

# %%
# categorical features in data
cat_features = config['data']['cat_features']

# %%
# save encoder and binarizer of the training data
encoder_train = joblib.load('./model/encoder_train.joblib')
lb_train = joblib.load('./model/lb_train.joblib')

# %%
# train-test split
train, test = train_test_split(df, test_size=config['model_training']['test_size'],
                               random_state=config['model_training']['random_state'],
                               stratify=df['salary'])

# %%
X_train, y_train, encoder, lb = process_data(
    test, categorical_features=cat_features,
    label="salary", training=False, encoder=encoder_train, lb=lb_train
)

# %%
preds = inference(model, X_train)#[0])#,:])

# %%
prediction = lb.inverse_transform(preds)#[9760]

# %%
prediction
# Out:
# array([' <=50K', ' <=50K', ' <=50K', ..., ' >50K', ' >50K', ' >50K'],
#       dtype='<U6')

# %%
len(prediction)
# Out:
# 9762

# %%
len(X_train)
# Out:
# 9762

# %%
test.head(50)
# Out:
#        age          workclass   fnlgt      education       marital-status  \
# 6623    72       Self-emp-inc  473748   Some-college   Married-civ-spouse
# 3688    30            Private  306383   Some-college             Divorced
# 25741   22            Private  229987   Some-college        Never-married
# 2391    22            Private  189950      Bachelors        Never-married
# 13787   46            Private  218329   Some-college        Never-married
# 2697    48            Private  320421        HS-grad   Married-civ-spouse
# 19322   23          Local-gov  210029   Some-college        Never-married
# 15922   58            Private  126104        Masters             Divorced
# 18568   23            Private  166527   Some-college        Never-married
# 18244   61          Local-gov  144723        Masters   Married-civ-spouse
# 20504   51          State-gov  285747        Masters   Married-civ-spouse
# 30222   47            Private   49298        HS-grad             Divorced
# 15385   22            Private  401762        HS-grad        Never-married
# 11814   36          State-gov  108320        Masters             Divorced
# 23098   38          Local-gov  177305      Bachelors   Married-civ-spouse
# 29415   18                  ?   25837           11th        Never-married
# 9856    43   Self-emp-not-inc  355856      Bachelors   Married-civ-spouse
# 19500   27                  ?  173800        Masters        Never-married
# 10833   17            Private  126779           11th        Never-married
# 31430   55          Local-gov  143949        Masters   Married-civ-spouse
# 20893   34            Private   90614     Assoc-acdm   Married-civ-spouse
# 20943   22          State-gov  309348   Some-college        Never-married
# 17090   30            Private  263150        HS-grad             Divorced
# 27823   35            Private  265662      Bachelors   Married-civ-spouse
# 22512   37            Private   82576    Prof-school             Divorced
# 19788   58            Private  111625      Bachelors              Widowed
# 19016   47            Private  155659   Some-college   Married-civ-spouse
# 25347   26            Private  108019        HS-grad        Never-married
# 20567   68                  ?  351402      Doctorate   Married-civ-spouse
# 21825   60   Self-emp-not-inc  264314   Some-college   Married-civ-spouse
# 3736    36                  ?   53606      Assoc-voc   Married-civ-spouse
# 9020    45            Private  140644        HS-grad   Married-civ-spouse
# 21443   34                  ?  170276      Bachelors   Married-civ-spouse
# 29835   52            Private   90189        7th-8th             Divorced
# 26491   25            Private  169679        HS-grad   Married-civ-spouse
# 22980   59            Private  195820        HS-grad   Married-civ-spouse
# 24599   57   Self-emp-not-inc  152030   Some-college   Married-civ-spouse
# 5686    41            Private   78410        HS-grad   Married-civ-spouse
# 3095    48       Self-emp-inc  200471      Bachelors   Married-civ-spouse
# 10720   19            Private   41400        HS-grad        Never-married
# 10573   51            Private  102615        Masters   Married-civ-spouse
# 32147   41            Private  151736           10th        Never-married
# 20613   32            Private  226883        HS-grad   Married-civ-spouse
# 18047   40            Private  175674      Bachelors   Married-civ-spouse
# 1790    30        Federal-gov  188569            9th   Married-civ-spouse
# 14672   35   Self-emp-not-inc  216256            9th   Married-civ-spouse
# 1108    41            Private  118212      Bachelors   Married-civ-spouse
# 21698   25            Private  108542      Bachelors        Never-married
# 24312   48   Self-emp-not-inc   52240      Assoc-voc   Married-civ-spouse
# 28589   40   Self-emp-not-inc   29036   Some-college        Never-married
#
#                occupation     relationship                 race      sex  \
# 6623      Exec-managerial          Husband                White     Male
# 3688    Handlers-cleaners    Not-in-family                White     Male
# 25741        Tech-support   Other-relative   Asian-Pac-Islander   Female
# 2391       Prof-specialty    Not-in-family                White     Male
# 13787        Craft-repair        Own-child                White     Male
# 2697                Sales          Husband                White     Male
# 19322        Adm-clerical        Own-child                White   Female
# 15922        Adm-clerical    Not-in-family                White   Female
# 18568     Exec-managerial        Own-child                Other   Female
# 18244     Exec-managerial          Husband                White     Male
# 20504      Prof-specialty          Husband                White     Male
# 30222               Sales    Not-in-family                White     Male
# 15385        Adm-clerical    Not-in-family                White   Female
# 11814      Prof-specialty        Unmarried                White     Male
# 23098      Prof-specialty          Husband                White     Male
# 29415                   ?        Own-child                White     Male
# 9856      Exec-managerial          Husband   Asian-Pac-Islander     Male
# 19500                   ?        Unmarried   Asian-Pac-Islander     Male
# 10833       Other-service        Own-child                Black     Male
# 31430      Prof-specialty             Wife                White   Female
# 20893        Tech-support          Husband                White     Male
# 20943        Adm-clerical    Not-in-family                White   Female
# 17090   Machine-op-inspct        Unmarried                White   Female
# 27823               Sales          Husband                White     Male
# 22512      Prof-specialty    Not-in-family                White     Male
# 19788     Exec-managerial        Unmarried                White     Male
# 19016        Craft-repair          Husband                White     Male
# 25347        Craft-repair        Own-child                White     Male
# 20567                   ?          Husband                White     Male
# 21825     Exec-managerial          Husband                White     Male
# 3736                    ?             Wife                White   Female
# 9020                Sales          Husband                White     Male
# 21443                   ?             Wife                White   Female
# 29835     Priv-house-serv        Own-child                Black   Female
# 26491    Transport-moving          Husband                White     Male
# 22980    Transport-moving          Husband                White     Male
# 24599               Sales             Wife                White   Female
# 5686         Adm-clerical             Wife                White   Female
# 3095      Exec-managerial          Husband                White     Male
# 10720   Handlers-cleaners        Own-child                White     Male
# 10573     Protective-serv          Husband                White     Male
# 32147   Machine-op-inspct    Not-in-family                White     Male
# 20613        Craft-repair          Husband                White     Male
# 18047               Sales          Husband                White     Male
# 1790         Tech-support          Husband                White     Male
# 14672        Craft-repair          Husband                White     Male
# 1108         Craft-repair          Husband                White     Male
# 21698     Exec-managerial        Own-child                White     Male
# 24312     Exec-managerial             Wife                White   Female
# 28589   Machine-op-inspct    Not-in-family                White     Male
#
#        hours-per-week  native-country  salary
# 6623               25   United-States    >50K
# 3688               50   United-States   <=50K
# 25741              32   United-States   <=50K
# 2391               55   United-States   <=50K
# 13787              40   United-States   <=50K
# 2697               50   United-States   <=50K
# 19322              20   United-States   <=50K
# 15922              45   United-States   <=50K
# 18568              40   United-States   <=50K
# 18244              60   United-States    >50K
# 20504              60   United-States    >50K
# 30222              50   United-States   <=50K
# 15385              55   United-States   <=50K
# 11814              30   United-States   <=50K
# 23098              38   United-States   <=50K
# 29415              72   United-States   <=50K
# 9856               50     Philippines   <=50K
# 19500              20          Taiwan   <=50K
# 10833              20   United-States   <=50K
# 31430              45   United-States    >50K
# 20893              10   United-States   <=50K
# 20943              15   United-States   <=50K
# 17090              20   United-States   <=50K
# 27823              40   United-States    >50K
# 22512              36   United-States    >50K
# 19788              40   United-States    >50K
# 19016              55   United-States    >50K
# 25347              40   United-States   <=50K
# 20567              70   United-States   <=50K
# 21825              35        Columbia   <=50K
# 3736                8   United-States   <=50K
# 9020               50   United-States    >50K
# 21443              10   United-States    >50K
# 29835              16   United-States   <=50K
# 26491              40   United-States   <=50K
# 22980              40   United-States    >50K
# 24599              25   United-States    >50K
# 5686               40   United-States    >50K
# 3095               40   United-States    >50K
# 10720              30   United-States   <=50K
# 10573              40   United-States    >50K
# 32147              40   United-States   <=50K
# 20613              40         Germany   <=50K
# 18047              50   United-States    >50K
# 1790               40   United-States   <=50K
# 14672              50   United-States   <=50K
# 1108               40   United-States    >50K
# 21698              35   United-States   <=50K
# 24312              25   United-States    >50K
# 28589              35   United-States   <=50K
